# %% [markdown]
# # Latihan Bab 1 — Apa itu Deep Learning?
# Notebook singkat untuk memeriksa pemahaman konsep dasar.

# %% [markdown]
# ## Latihan 1
# Lengkapi tiga definisi berikut dengan bahasamu sendiri.

# %%
ai = ""
machine_learning = ""
deep_learning = ""

print("AI:", ai)
print("Machine learning:", machine_learning)
print("Deep learning:", deep_learning)

# %% [markdown]
# ## Latihan 2
# Tentukan mana yang merupakan data, model, dan prediksi pada contoh pengenal gambar kucing.

# %%
jawaban = {
    "data": "",
    "model": "",
    "prediksi": ""
}
jawaban
